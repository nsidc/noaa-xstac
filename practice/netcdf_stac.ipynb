# %%
import urllib.request
import xarray as xr
import xstac
import pandas as pd
import pathlib
import pystac
import json
import datetime

# %%
url = ("https://noaadata.apps.nsidc.org/NOAA/G02202_V4/"
       "north/daily/2023/seaice_conc_daily_nh_20230101_f17_v04r00.nc")
file = "seaice_conc_daily_nh_20230101_f17_v04r00.nc"

# %%
if not pathlib.Path(file).exists():
    urllib.request.urlretrieve(url, file)

# %%
ds = xr.open_dataset(file)

# %%
print(len(ds.time))
# Out:
# 1

# %%
int(ds.time.min().data)
# Out:
# 1672531200000000000

# %%
template = {
        "id": "id",
        "type": "Feature",
        "links": [],
        "geometry": None,  # generated by xstac
        "stac_version": "1.0.0",
        "properties": {
            "start_datetime": "2023-01-01T00:00:00Z",
            "end_datetime": "2024-04-01T00:00:00Z",
        },
        "assets": {},
    }

# %%
result = xstac.xarray_to_stac(
        ds,
        template,
        temporal_dimension="time",
        x_dimension="xgrid",
        y_dimension="ygrid",
        reference_system="4326",  # TODO: this is probably incorrect.
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 result = xstac.xarray_to_stac(
#       2         ds,
#       3         template,
#       4         temporal_dimension="time",
#       5         x_dimension="xgrid",
#       6         y_dimension="ygrid",
#       7         reference_system="4326",  # TODO: this is probably incorrect.
#       8     )
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/site-packages/xstac/_xstac.py:482, in xarray_to_stac(ds, template, temporal_dimension, temporal_extent, temporal_values, temporal_step, x_dimension, x_extent, x_values, x_step, y_dimension, y_extent, y_values, y_step, reference_system, vertical_dimension, vertical_extent, vertical_values, vertical_step, validate, kerchunk_indices, **additional_dimensions)
#     480     if isinstance(stac_obj, pystac.Collection):
#     481         stac_obj.normalize_hrefs("/")
# --> 482     stac_obj.validate()
#     483 return stac_obj
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/site-packages/pystac/stac_object.py:84, in STACObject.validate(self, validator)
#      68 """Validate this STACObject.
#      69
#      70 Returns a list of validation results, which depends on the validation
#    (...)
#      80     STACValidationError
#      81 """
#      82 import pystac.validation
# ---> 84 return pystac.validation.validate(self, validator=validator)
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/site-packages/pystac/validation/__init__.py:43, in validate(stac_object, validator)
#      22 def validate(
#      23     stac_object: STACObject,
#      24     validator: STACValidator | None = None,
#      25 ) -> list[Any]:
#      26     """Validates a :class:`~pystac.STACObject`.
#      27
#      28     Args:
#    (...)
#      41         STACValidationError
#      42     """
# ---> 43     return validate_dict(
#      44         stac_dict=stac_object.to_dict(),
#      45         stac_object_type=stac_object.STAC_OBJECT_TYPE,
#      46         stac_version=pystac.get_stac_version(),
#      47         extensions=stac_object.stac_extensions,
#      48         href=stac_object.get_self_href(),
#      49         validator=validator,
#      50     )
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/site-packages/pystac/validation/__init__.py:121, in validate_dict(stac_dict, stac_object_type, stac_version, extensions, href, validator)
#     118     extensions = [uri for uri in map(_get_uri, extensions) if uri is not None]
#     120 validator = validator or RegisteredValidator.get_validator()
# --> 121 return validator.validate(
#     122     stac_dict, stac_object_type, stac_version, extensions, href
#     123 )
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/site-packages/pystac/validation/stac_validator.py:115, in STACValidator.validate(self, stac_dict, stac_object_type, stac_version, extensions, href)
#     110 results: list[Any] = []
#     112 # Pass the dict through JSON serialization and parsing, otherwise
#     113 # some valid properties can be marked as invalid (e.g. tuples in
#     114 # coordinate sequences for geometries).
# --> 115 json_dict = json.loads(json.dumps(stac_dict))
#     116 core_result = self.validate_core(
#     117     json_dict, stac_object_type, stac_version, href
#     118 )
#     119 if core_result is not None:
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~/mambaforge/envs/noaa-ai/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type ndarray is not JSON serializable

# %%
result.assets["data"] = pystac.Asset(
    href=url, title="sea_ice_area_fraction", roles=["data"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 result.assets["data"] = pystac.Asset(
#       2     href=url, title="sea_ice_area_fraction", roles=["data"]
#       3 )
#
# NameError: name 'result' is not defined
